# %% [markdown]
# | Category | Paper Title | Authors | Year |
# |---|---|---|---|
# | Origin paper | *Language Models are Unsupervised Multitask Learners* | Alec Radford, Jeff Wu, Rewon Child, David Luan, Dario Amodei, Ilya Sutskever | 2019 |
# | Prior works | *Improving Language Understanding by Generative Pre-Training* | Alec Radford, Karthik Narasimhan | 2018 |
# | Prior works | *BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding* | Jacob Devlin, Ming-Wei Chang, Kenton Lee, Kristina Toutanova | 2019 |
# | Prior works | *RoBERTa: A Robustly Optimized BERT Pretraining Approach* | Yinhan Liu, Myle Ott, Naman Goyal, Jingfei Du, Mandar Joshi, Danqi Chen, Omer Levy, Mike Lewis, Luke Zettlemoyer, Veselin Stoyanov | 2019 |
# | Prior works | *Attention is All you Need* | Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Lukasz Kaiser, Illia Polosukhin | 2017 |
# | Prior works | *XLNet: Generalized Autoregressive Pretraining for Language Understanding* | Zhilin Yang, Zihang Dai, Yiming Yang, Jaime Carbonell, Ruslan Salakhutdinov, Quoc V. Le | 2019 |
# | Prior works | *ALBERT: A Lite BERT for Self-supervised Learning of Language Representations* | Zhenzhong Lan, Mingda Chen, Sebastian Goodman, Kevin Gimpel, Piyush Sharma, Radu Soricut | 2019 |
# | Derivative works | *DeBERTa: Decoding-enhanced BERT with Disentangled Attention* | Pengcheng He, Xiaodong Liu, Jianfeng Gao, Weizhu Chen | 2020 |
# | Prior works | *GLUE: A Multi-Task Benchmark and Analysis Platform for Natural Language Understanding* | Alex Wang, Amanpreet Singh, Julian Michael, Felix Hill, Omer Levy, Samuel R. Bowman | 2018 |
# | Related works | *HuggingFace's Transformers: State-of-the-art Natural Language Processing* | Thomas Wolf, Lysandre Debut, Victor Sanh, Julien Chaumond, Clément Delangue, Anthony Moi, Pierric Cistac, Tim Rault, Rémi Louf, Morgan Funtowicz, Joe Davison, Sam Shleifer, Patrick von Platen, Clara Ma, Yacine Jernite, Julien Plu, Canwen Xu, Teven Le Scao, Sylvain Gugger, Mariama Drame, Quentin Lhoest, Alexander M. Rush | 2019 |
# | Prior works | *Deep Contextualized Word Representations* | Matthew E. Peters, Mark Neumann, Mohit Iyyer, Matt Gardner, Christopher Clark, Kenton Lee, Luke Zettlemoyer | 2018 |
# | Derivative works | *DeBERTaV3: Improving DeBERTa using ELECTRA-Style Pre-Training with Gradient-Disentangled Embedding Sharing* | Pengcheng He, Jianfeng Gao, Weizhu Chen | 2021 |
# | Related works | *Learning Transferable Visual Models From Natural Language Supervision* | Alec Radford, Jong Wook Kim, Chris Hallacy, Aditya Ramesh, Gabriel Goh, Sandhini Agarwal, Girish Sastry, Amanda Askell, Pamela Mishkin, Jack Clark, Gretchen Krueger, Ilya Sutskever | 2021 |
# | Prior works | *GloVe: Global Vectors for Word Representation* | Jeffrey Pennington, Richard Socher, Christopher D. Manning | 2014 |
# | Related works | *Human vs. Muppet: A Conservative Estimate of Human Performance on the GLUE Benchmark* | Nikita Nangia, Samuel R. Bowman | 2019 |
# | Derivative works | *MiniLM: Deep Self-Attention Distillation for Task-Agnostic Compression of Pre-Trained Transformers* | Wenhui Wang, Furu Wei, Li Dong, Hangbo Bao, Nan Yang, Ming Zhou | 2020 |
# | Related works | *MPNet: Masked and Permuted Pre-training for Language Understanding* | Kaitao Song, Xu Tan, Tao Qin, Jianfeng Lu, Tie-Yan Liu | 2020 |
# | Derivative works | *The Power of Scale for Parameter-Efficient Prompt Tuning* | Brian Lester, Rami Al-Rfou, Noah Constant | 2021 |
# | Derivative works | *MiniLMv2: Multi-Head Self-Attention Relation Distillation for Compressing Pretrained Transformers* | Wenhui Wang, Hangbo Bao, Shaohan Huang, Li Dong, Furu Wei | 2020 |
# | Derivative works | *UniLMv2: Pseudo-Masked Language Models for Unified Language Model Pre-Training* | Hangbo Bao, Li Dong, Furu Wei, Wenhui Wang, Nan Yang, Xiaodong Liu, Yu Wang, Songhao Piao, Jianfeng Gao, Ming Zhou, Hsiao-Wuen Hon | 2020 |
# | Derivative works | *Training language models to follow instructions with human feedback* | Long Ouyang, Jeff Wu, Xu Jiang, Diogo Almeida, Carroll L. Wainwright, Pamela Mishkin, Chong Zhang, Sandhini Agarwal, Katarina Slama, Alex Ray, John Schulman, Jacob Hilton, Fraser Kelton, Luke E. Miller, M. Simens, Amanda Askell, Peter Welinder, Paul Christiano, Jan Leike, Ryan J. Lowe | 2022 |
# | Related works | *An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale* | Alexey Dosovitskiy, Lucas Beyer, Alexander Kolesnikov, Dirk Weissenborn, Xiaohua Zhai, Thomas Unterthiner, Mostafa Dehghani, Matthias Minderer, Georg Heigold, Sylvain Gelly, Jakob Uszkoreit, Neil Houlsby | 2020 |
# | Prior works | *Sentence Encoders on STILTs: Supplementary Training on Intermediate Labeled-data Tasks* | Jason Phang, Thibault Févry, Samuel R. Bowman | 2018 |
# | Related works | *PaLM: Scaling Language Modeling with Pathways* | A. Chowdhery, Sharan Narang, Jacob Devlin, Maarten Bosma, Gaurav Mishra, Adam Roberts, Paul Barham, Hyung Won Chung, Charles Sutton, Sebastian Gehrmann, Parker Schuh, Kensen Shi, Sasha Tsvyashchenko, Joshua Maynez, Abhishek Rao, Parker Barnes, Yi Tay, Noam Shazeer, Vinodkumar Prabhakaran, Emily Reif, Nan Du, Ben Hutchinson, Reiner Pope, James Bradbury, Jacob Austin, Michael Isard, Guy Gur-Ari, Pengcheng Yin, Toju Duke, Anselm Levskaya, Sanjay Ghemawat, Sunipa Dev, H. Michalewski, Xavier García, Vedant Misra, Kevin Robinson, L. Fedus, Denny Zhou, Daphne Ippolito, Donald Luan, Hyeontaek Lim, Barret Zoph, Alexander Spiridonov, Ryan Sepassi, David Dohan, Shivani Agrawal, Mark Omernick, Andrew M. Dai, Thanumalayan Sankaranarayana Pillai, Marie Pellat, Aitor Lewkowycz, Erica Moreira, Rewon Child, Oleksandr Polozov, Katherine Lee, Zongwei Zhou, Xuezhi Wang, Brennan Saeta, Mark Díaz, Orhan Firat, Michele Catasta, Jason Wei, Katherine Meier-Hellstern, Douglas Eck, Jeff Dean, Slav Petrov, Noah Fiedel | 2022 |
# | Prior works | *MASS: Masked Sequence to Sequence Pre-training for Language Generation* | Kaitao Song, Xu Tan, Tao Qin, Jianfeng Lu, Tie-Yan Liu | 2019 |
# | Prior works | *Cloze-driven Pretraining of Self-attention Networks* | Alexei Baevski, Sergey Edunov, Yinhan Liu, Luke Zettlemoyer, Michael Auli | 2019 |
# | Related works | *On the Role of Bidirectionality in Language Model Pre-Training* | Mikel Artetxe, Jingfei Du, Naman Goyal, Luke Zettlemoyer, Veselin Stoyanov | 2022 |
# | Derivative works | *StructBERT: Incorporating Language Structures into Pre-training for Deep Language Understanding* | Wei Wang, Bin Bi, Ming Yan, Chen Wu, Zuyi Bao, Liwei Peng, Luo Si | 2019 |
# | Related works | *Unsupervised Cross-lingual Representation Learning at Scale* | Alexis Conneau, Kartikay Khandelwal, Naman Goyal, Vishrav Chaudhary, Guillaume Wenzek, Francisco Guzmán, Edouard Grave, Myle Ott, Luke Zettlemoyer, Veselin Stoyanov | 2019 |
# | Related works | *Looking for ELMo's friends: Sentence-Level Pretraining Beyond Language Modeling* | Samuel R. Bowman, Ellie Pavlick, Edouard Grave, Benjamin Van Durme, Alex Wang, Jan Hula, Patrick Xia, R. Pappagari, R. Thomas McCoy, Roma Patel, Najoung Kim, Ian Tenney, Yinghui Huang, Katherin Yu, Shuning Jin, Berlin Chen | 2018 |
# | Related works | *To Tune or Not to Tune? Adapting Pretrained Representations to Diverse Tasks* | Matthew E. Peters, Sebastian Ruder, Noah A. Smith | 2019 |
# | Derivative works | *Adversarial Training for Large Neural Language Models* | Xiaodong Liu, Hao Cheng, Pengcheng He, Weizhu Chen, Yu Wang, Hoifung Poon, Jianfeng Gao | 2020 |
# | Related works | *Unifying Question Answering and Text Classification via Span Extraction* | Nitish Keskar, Bryan McCann, Caiming Xiong, Richard Socher | 2019 |
# | Derivative works | *Prefix-Tuning: Optimizing Continuous Prompts for Generation* | Xiang Lisa Li, Percy Liang | 2021 |
# | Derivative works | *Entailment as Few-Shot Learner* | Sinong Wang, Han Fang, Madian Khabsa, Hanzi Mao, Hao Ma | 2021 |
# | Derivative works | *MobileBERT: a Compact Task-Agnostic BERT for Resource-Limited Devices* | Zhiqing Sun, Hongkun Yu, Xiaodan Song, Renjie Liu, Yiming Yang, Denny Zhou | 2020 |
# | Related works | *Sparsely Activated Mixture-of-Experts are Robust Multi-Task Learners* | Shashank Gupta, Subhabrata Mukherjee, Kuntal Kumar Subudhi, Eduardo González, Damien Jose, Ahmed Hassan Awadallah, Jianfeng Gao | 2022 |
# | Prior works | *Transformer-XL: Attentive Language Models beyond a Fixed-Length Context* | Zihang Dai, Zhilin Yang, Yiming Yang, Jaime Carbonell, Quoc V. Le, Ruslan Salakhutdinov | 2019 |
# | Related works | *Intermediate Task Model Intermediate Task Output BERT Input Text Intermediate Task Model Intermediate Task Output ELMo BiLSTM Input Text Target Task Model Target Task Output Intermediate Task-Trained BERT Input Text Pretraining Task Model Pretraining Task Output BiLSTM* | Alex Wang, Jan Hula, Patrick Xia, R. Pappagari, R. Thomas McCoy, Roma Patel, Najoung Kim, Ian Tenney, Yinghui Huang, Katherin Yu, Shuning Jin, Berlin Chen, Benjamin Van Durme, Edouard Grave, Ellie Pavlick, Samuel R. Bowman | 2019 |
# | Related works | *HyperGrid Transformers: Towards A Single Model for Multiple Tasks* | Yi Tay, Zhe Zhao, Dara Bahri, Donald Metzler, Da-Cheng Juan | 2021 |
