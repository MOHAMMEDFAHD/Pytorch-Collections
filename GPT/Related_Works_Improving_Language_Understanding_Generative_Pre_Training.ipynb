# %% [markdown]
# | Category | Paper Title | Authors | Year |
# |---|---|---|---|
# | Origin paper | *Improving Language Understanding by Generative Pre-Training* | Alec Radford, Karthik Narasimhan | 2018 |
# | Prior works | *RoBERTa: A Robustly Optimized BERT Pretraining Approach* | Yinhan Liu, Myle Ott, Naman Goyal, Jingfei Du, Mandar Joshi, Danqi Chen, Omer Levy, Mike Lewis, Luke Zettlemoyer, Veselin Stoyanov | 2019 |
# | Prior works | *Deep Contextualized Word Representations* | Matthew E. Peters, Mark Neumann, Mohit Iyyer, Matt Gardner, Christopher Clark, Kenton Lee, Luke Zettlemoyer | 2018 |
# | Prior works | *ALBERT: A Lite BERT for Self-supervised Learning of Language Representations* | Zhenzhong Lan, Mingda Chen, Sebastian Goodman, Kevin Gimpel, Piyush Sharma, Radu Soricut | 2019 |
# | Prior works | *GLUE: A Multi-Task Benchmark and Analysis Platform for Natural Language Understanding* | Alex Wang, Amanpreet Singh, Julian Michael, Felix Hill, Omer Levy, Samuel R. Bowman | 2018 |
# | Derivative works | *Language Models are Few-Shot Learners* | Tom B. Brown, Benjamin Mann, Nick Ryder, Melanie Subbiah, Jared Kaplan, Prafulla Dhariwal, Arvind Neelakantan, Pranav Shyam, Girish Sastry, Amanda Askell, Sandhini Agarwal, Ariel Herbert-Voss, Gretchen Krueger, Tom Henighan, Rewon Child, Aditya Ramesh, Daniel M. Ziegler, Jeff Wu, Clemens Winter, Christopher Hesse, Mark Chen, Eric Sigler, Mateusz Litwin, Scott Gray, Benjamin Chess, Jack Clark, Christopher Berner, Sam McCandlish, Alec Radford, Ilya Sutskever, Dario Amodei | 2020 |
# | Derivative works | *DeBERTa: Decoding-enhanced BERT with Disentangled Attention* | Pengcheng He, Xiaodong Liu, Jianfeng Gao, Weizhu Chen | 2020 |
# | Prior works | *MASS: Masked Sequence to Sequence Pre-training for Language Generation* | Kaitao Song, Xu Tan, Tao Qin, Jianfeng Lu, Tie-Yan Liu | 2019 |
# | Related works | *To Tune or Not to Tune? Adapting Pretrained Representations to Diverse Tasks* | Matthew E. Peters, Sebastian Ruder, Noah A. Smith | 2019 |
# | Prior works | *BART: Denoising Sequence-to-Sequence Pre-training for Natural Language Generation, Translation, and Comprehension* | Mike Lewis, Yinhan Liu, Naman Goyal, Marjan Ghazvininejad, Abdelrahman Mohamed, Omer Levy, Veselin Stoyanov, Luke Zettlemoyer | 2019 |
# | Prior works | *SpanBERT: Improving Pre-training by Representing and Predicting Spans* | Mandar Joshi, Danqi Chen, Yinhan Liu, Daniel S. Weld, Luke Zettlemoyer, Omer Levy | 2019 |
# | Related works | *HuggingFace's Transformers: State-of-the-art Natural Language Processing* | Thomas Wolf, Lysandre Debut, Victor Sanh, Julien Chaumond, Clément Delangue, Anthony Moi, Pierric Cistac, Tim Rault, Rémi Louf, Morgan Funtowicz, Joe Davison, Sam Shleifer, Patrick von Platen, Clara Ma, Yacine Jernite, Julien Plu, Canwen Xu, Teven Le Scao, Sylvain Gugger, Mariama Drame, Quentin Lhoest, Alexander M. Rush | 2019 |
# | Prior works | *A Broad-Coverage Challenge Corpus for Sentence Understanding through Inference* | Adina Williams, Nikita Nangia, Samuel R. Bowman | 2017 |
# | Related works | *Looking for ELMo's friends: Sentence-Level Pretraining Beyond Language Modeling* | Samuel R. Bowman, Ellie Pavlick, Edouard Grave, Benjamin Van Durme, Alex Wang, Jan Hula, Patrick Xia, R. Pappagari, R. Thomas McCoy, Roma Patel, Najoung Kim, Ian Tenney, Yinghui Huang, Katherin Yu, Shuning Jin, Berlin Chen | 2018 |
# | Prior works | *Unified Language Model Pre-training for Natural Language Understanding and Generation* | Li Dong, Nan Yang, Wenhui Wang, Furu Wei, Xiaodong Liu, Yu Wang, Jianfeng Gao, Ming Zhou, Hsiao-Wuen Hon | 2019 |
# | Prior works | *ERNIE: Enhanced Language Representation with Informative Entities* | Zhengyan Zhang, Xu Han, Zhiyuan Liu, Xin Jiang, Maosong Sun, Qun Liu | 2019 |
# | Derivative works | *MiniLM: Deep Self-Attention Distillation for Task-Agnostic Compression of Pre-Trained Transformers* | Wenhui Wang, Furu Wei, Li Dong, Hangbo Bao, Nan Yang, Ming Zhou | 2020 |
# | Prior works | *GloVe: Global Vectors for Word Representation* | Jeffrey Pennington, Richard Socher, Christopher D. Manning | 2014 |
# | Prior works | *Universal Language Model Fine-tuning for Text Classification* | Jeremy Howard, Sebastian Ruder | 2018 |
# | Derivative works | *MPNet: Masked and Permuted Pre-training for Language Understanding* | Kaitao Song, Xu Tan, Tao Qin, Jianfeng Lu, Tie-Yan Liu | 2020 |
# | Derivative works | *The Power of Scale for Parameter-Efficient Prompt Tuning* | Brian Lester, Rami Al-Rfou, Noah Constant | 2021 |
# | Derivative works | *MobileBERT: a Compact Task-Agnostic BERT for Resource-Limited Devices* | Zhiqing Sun, Hongkun Yu, Xiaodan Song, Renjie Liu, Yiming Yang, Denny Zhou | 2020 |
# | Related works | *Can You Tell Me How to Get Past Sesame Street? Sentence-Level Pretraining Beyond Language Modeling* | Alex Wang, Jan Hula, Patrick Xia, R. Pappagari, R. Thomas McCoy, Roma Patel, Najoung Kim, Ian Tenney, Yinghui Huang, Katherin Yu, Shuning Jin, Berlin Chen, Benjamin Van Durme, Edouard Grave, Ellie Pavlick, Samuel R. Bowman | 2018 |
# | Related works | *InferLite: Simple Universal Sentence Representations from Natural Language Inference Data* | J. Kiros, William Chan | 2018 |
# | Derivative works | *Training language models to follow instructions with human feedback* | Long Ouyang, Jeff Wu, Xu Jiang, Diogo Almeida, Carroll L. Wainwright, Pamela Mishkin, Chong Zhang, Sandhini Agarwal, Katarina Slama, Alex Ray, John Schulman, Jacob Hilton, Fraser Kelton, Luke E. Miller, M. Simens, Amanda Askell, Peter Welinder, Paul Christiano, Jan Leike, Ryan J. Lowe | 2022 |
# | Prior works | *SQuAD: 100,000+ Questions for Machine Comprehension of Text* | Pranav Rajpurkar, Jian Zhang, Konstantin Lopyrev, Percy Liang | 2016 |
# | Derivative works | *SMART: Robust and Efficient Fine-Tuning for Pre-trained Natural Language Models through Principled Regularized Optimization* | Haoming Jiang, Pengcheng He, Weizhu Chen, Xiaodong Liu, Jianfeng Gao, Tianyi Zhao | 2019 |
# | Derivative works | *ConvBERT: Improving BERT with Span-based Dynamic Convolution* | Zihang Jiang, Weihao Yu, Daquan Zhou, Yunpeng Chen, Jiashi Feng, Shuicheng Yan | 2020 |
# | Prior works | *Sentence Encoders on STILTs: Supplementary Training on Intermediate Labeled-data Tasks* | Jason Phang, Thibault Févry, Samuel R. Bowman | 2018 |
# | Related works | *Unsupervised Cross-lingual Representation Learning at Scale* | Alexis Conneau, Kartikay Khandelwal, Naman Goyal, Vishrav Chaudhary, Guillaume Wenzek, Francisco Guzmán, Edouard Grave, Myle Ott, Luke Zettlemoyer, Veselin Stoyanov | 2019 |
# | Derivative works | *TinyBERT: Distilling BERT for Natural Language Understanding* | Xiaoqi Jiao, Yichun Yin, Lifeng Shang, Xin Jiang, Xiao Chen, Linlin Li, F. Wang, Qun Liu | 2019 |
# | Prior works | *Attention is All you Need* | Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Lukasz Kaiser, Illia Polosukhin | 2017 |
# | Related works | *Multi-Task Deep Neural Networks for Natural Language Understanding* | Xiaodong Liu, Pengcheng He, Weizhu Chen, Jianfeng Gao | 2019 |
# | Derivative works | *Finetuned Language Models Are Zero-Shot Learners* | Jason Wei, Maarten Bosma, Vincent Y. Zhao, Kelvin Guu, Adams Wei Yu, Brian Lester, Nan Du, Andrew M. Dai, Quoc V. Le | 2021 |
# | Prior works | *Cross-lingual Language Model Pretraining* | Guillaume Lample, Alexis Conneau | 2019 |
# | Prior works | *Automatically Constructing a Corpus of Sentential Paraphrases* | William Dolan, Chris Brockett | 2005 |
# | Related works | *Visualizing and Understanding the Effectiveness of BERT* | Y. Hao, Li Dong, Furu Wei, Ke Xu | 2019 |
# | Related works | *Explorations into the Use of Word Embedding in Math Search and Math Semantics* | Abdou Youssef, Bruce Miller | 2019 |
# | Related works | *Dissecting Contextual Word Embeddings: Architecture and Representation* | Matthew E. Peters, Mark Neumann, Luke Zettlemoyer, Wen-tau Yih | 2018 |
# | Derivative works | *Prefix-Tuning: Optimizing Continuous Prompts for Generation* | Xiang Lisa Li, Percy Liang | 2021 |
# | Derivative works | *Toward Efficient Language Model Pretraining and Downstream Adaptation via Self-Evolution: A Case Study on SuperGLUE* | Qihuang Zhong, Liang Ding, Yibing Zhan, Y. Qiao, Yonggang Wen, Li Shen, Juhua Liu, Baosheng Yu, Bo Du, Yixin Chen, Xinbo Gao, Chun Miao, Xiaoou Tang, Dacheng Tao | 2022 |
