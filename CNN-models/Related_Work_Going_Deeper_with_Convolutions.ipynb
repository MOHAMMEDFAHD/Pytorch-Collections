# %% [markdown]
# # https://arxiv.org/pdf/1409.4842

# %% [markdown]
# ## Going Deeper with Convolutions — Related Work
#
#
# | Title | Authors | Year |
# |------|--------|------|
# | Going Deeper with Convolutions | Christian Szegedy, Wei Liu, Yangqing Jia, P. Sermanet, Scott E. Reed, Dragomir Anguelov, D. Erhan, Vincent Vanhoucke, Andrew Rabinovich | 2014 |
# | ImageNet Classification with Deep Convolutional Neural Networks | A. Krizhevsky, I. Sutskever, Geoffrey E. Hinton | 2012 |
# | Rethinking the Inception Architecture for Computer Vision | Christian Szegedy, Vincent Vanhoucke, Sergey Ioffe, Jonathon Shlens, Z. Wojna | 2015 |
# | Gradient-based Learning Applied to Document Recognition | Yann LeCun, L. Bottou, Yoshua Bengio, P. Haffner | 1998 |
# | Inception-v4, Inception-ResNet and the Impact of Residual Connections on Learning | Christian Szegedy, Sergey Ioffe, Vincent Vanhoucke, Alexander A. Alemi | 2016 |
# | Rich Feature Hierarchies for Accurate Object Detection and Semantic Segmentation | Ross B. Girshick, Jeff Donahue, Trevor Darrell, J. Malik | 2013 |
# | ImageNet: A Large-Scale Hierarchical Image Database | Jia Deng, Wei Dong, R. Socher, Li-Jia Li, K. Li, Li Fei-Fei | 2009 |
# | Visualizing and Understanding Convolutional Networks | Matthew D. Zeiler, R. Fergus | 2013 |
# | MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Applications | Andrew G. Howard, Menglong Zhu, Bo Chen, Dmitry Kalenichenko, Weijun Wang, Tobias Weyand, M. Andreetto, Hartwig Adam | 2017 |
# | Caffe: Convolutional Architecture for Fast Feature Embedding | Yangqing Jia, Evan Shelhamer, Jeff Donahue, Sergey Karayev, Jonathan Long, Ross B. Girshick, S. Guadarrama, Trevor Darrell | 2014 |
# | Region-Based Convolutional Networks for Accurate Object Detection and Segmentation | Ross B. Girshick, Jeff Donahue, Trevor Darrell, Jitendra Malik | 2016 |
# | Xception: Deep Learning with Depthwise Separable Convolutions | François Chollet | 2016 |
# | Delving Deep into Rectifiers: Surpassing Human-Level Performance on ImageNet Classification | Kaiming He, X. Zhang, Shaoqing Ren, Jian Sun | 2015 |
# | ShuffleNet: An Extremely Efficient Convolutional Neural Network for Mobile Devices | Xiangyu Zhang, Xinyu Zhou, Mengxiao Lin, Jian Sun | 2017 |
# | YOLO9000: Better, Faster, Stronger | Joseph Redmon, Ali Farhadi | 2016 |
# | Deep Learning | Xingbang Hao, Guigang Zhang, Shang Ma | 2016 |
# | Microsoft COCO: Common Objects in Context | Tsung-Yi Lin, M. Maire, Serge J. Belongie, James Hays, P. Perona, Deva Ramanan, Piotr Dollár, C. L. Zitnick | 2014 |
# | YOLOv3: An Incremental Improvement | Joseph Redmon, Ali Farhadi | 2018 |
# | U-Net: Convolutional Networks for Biomedical Image Segmentation | O. Ronneberger, P. Fischer, T. Brox | 2015 |
# | Mask R-CNN | Kaiming He, Georgia Gkioxari, Piotr Dollár, Ross B. Girshick | 2017 |
# | Network In Network | Min Lin, Qiang Chen, Shuicheng Yan | 2013 |
# | R-FCN: Object Detection via Region-based Fully Convolutional Networks | Jifeng Dai, Yi Li, Kaiming He, Jian Sun | 2016 |
# | How Transferable Are Features in Deep Neural Networks? | J. Yosinski, J. Clune, Yoshua Bengio, Hod Lipson | 2014 |
# | OverFeat: Integrated Recognition, Localization and Detection using Convolutional Networks | P. Sermanet, D. Eigen, Xiang Zhang, Michaël Mathieu, R. Fergus, Yann LeCun | 2013 |
# | Simultaneous Detection and Segmentation | Bharath Hariharan, Pablo Arbeláez, Ross B. Girshick, Jitendra Malik | 2014 |
# | Convolutional Neural Networks at Constrained Time Cost | Kaiming He, Jian Sun | 2014 |
# | An Image is Worth 16×16 Words: Transformers for Image Recognition at Scale | Alexey Dosovitskiy, Lucas Beyer, Alexander Kolesnikov, Dirk Weissenborn, Xiaohua Zhai, Thomas Unterthiner, Mostafa Dehghani, M. Minderer, G. Heigold, S. Gelly, Jakob Uszkoreit, N. Houlsby | 2020 |
# | The PASCAL Visual Object Classes (VOC) Challenge | International Journal of Computer Vision Manuscript | — |
# | Learning Transferable Architectures for Scalable Image Recognition | Barret Zoph, Vijay Vasudevan, Jonathon Shlens, Quoc V. Le | 2017 |
# | Long Short-Term Memory | Sepp Hochreiter, J. Schmidhuber | 1997 |
# | ESPACE: Accelerating Convolutional Neural Networks via Eliminating Spatial and Channel Redundancy | Shaohui Lin, R. Ji, Chao Chen, Feiyue Huang | 2017 |
# | DSSD: Deconvolutional Single Shot Detector | Cheng-Yang Fu, W. Liu, A. Ranga, A. Tyagi, A. Berg | 2017 |
# | Beyond Bounding Boxes: Precise Localization of Objects in Images | Bharath Hariharan, Jitendra Malik | 2015 |
# | Edge Boxes: Locating Object Proposals from Edges | C. L. Zitnick, Piotr Dollár | 2014 |
# | Training Region-Based Object Detectors with Online Hard Example Mining | Abhinav Shrivastava, A. Gupta, Ross B. Girshick | 2016 |
# | RON: Reverse Connection with Objectness Prior Networks for Object Detection | Tao Kong, F. Sun, Anbang Yao, Huaping Liu, Ming Lu, Yurong Chen | 2017 |
# | Object Detection with Discriminatively Trained Part Based Models | Pedro F. Felzenszwalb, Ross B. Girshick, David A. McAllester, Deva Ramanan | 2010 |
# | Return of the Devil in the Details: Delving Deep into Convolutional Nets | Ken Chatfield, K. Simonyan, A. Vedaldi, Andrew Zisserman | 2014 |
# | Learning to Segment Object Candidates | Pedro H. O. Pinheiro, R. Collobert, Piotr Dollár | 2015 |
# | Inside-Outside Net: Detecting Objects in Context with Skip Pooling and Recurrent Neural Networks | Sean Bell, C. L. Zitnick, Kavita Bala, Ross B. Girshick | 2015 |
# | Training Data-Efficient Image Transformers & Distillation Through Attention | Hugo Touvron, M. Cord, Matthijs Douze, Francisco Massa, Alexandre Sablayrolles, Hervé Jégou | 2020 |
