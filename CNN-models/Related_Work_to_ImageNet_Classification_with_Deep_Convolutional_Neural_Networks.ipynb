# %% [markdown]
# ## Related Work to *ImageNet Classification with Deep Convolutional Neural Networks*
#
#
#
# | Title | Authors | Year |
# |------|---------|------|
# | ImageNet classification with deep convolutional neural networks | A. Krizhevsky, I. Sutskever, Geoffrey E. Hinton | 2012 |
# | Very Deep Convolutional Networks for Large-Scale Image Recognition | K. Simonyan, Andrew Zisserman | 2014 |
# | ImageNet Large Scale Visual Recognition Challenge | Olga Russakovsky, Jia Deng, Hao Su, J. Krause, S. Satheesh, Sean Ma, Zhiheng Huang, A. Karpathy, A. Khosla, Michael S. Bernstein, A. Berg, Li Fei-Fei | 2014 |
# | ImageNet: A large-scale hierarchical image database | Jia Deng, Wei Dong, R. Socher, Li-Jia Li, K. Li, Li Fei-Fei | 2009 |
# | Densely Connected Convolutional Networks | Gao Huang, Zhuang Liu, Kilian Q. Weinberger | 2016 |
# | Rich Feature Hierarchies for Accurate Object Detection and Semantic Segmentation | Ross B. Girshick, Jeff Donahue, Trevor Darrell, J. Malik | 2013 |
# | Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition | Kaiming He, X. Zhang, Shaoqing Ren, Jian Sun | 2014 |
# | Convolutional neural networks at constrained time cost | Kaiming He, Jian Sun | 2014 |
# | Fast R-CNN | Ross B. Girshick | 2015 |
# | Adam: A Method for Stochastic Optimization | Diederik P. Kingma, Jimmy Ba | 2014 |
# | Microsoft COCO: Common Objects in Context | Tsung-Yi Lin, M. Maire, Serge J. Belongie, James Hays, P. Perona, Deva Ramanan, Piotr Dollár, C. L. Zitnick | 2014 |
# | Caffe: Convolutional Architecture for Fast Feature Embedding | Yangqing Jia, Evan Shelhamer, Jeff Donahue, Sergey Karayev, Jonathan Long, Ross B. Girshick, S. Guadarrama, Trevor Darrell | 2014 |
# | Learning Deep Features for Discriminative Localization | Bolei Zhou, A. Khosla, Àgata Lapedriza, A. Oliva, A. Torralba | 2015 |
# | Learning Multiple Layers of Features from Tiny Images | A. Krizhevsky | 2009 |
# | MobileNetV2: Inverted Residuals and Linear Bottlenecks | M. Sandler, Andrew G. Howard, Menglong Zhu, A. Zhmoginov, Liang-Chieh Chen | 2018 |
# | Xception: Deep Learning with Depthwise Separable Convolutions | François Chollet | 2016 |
# | Deep Learning | Yann LeCun, Yoshua Bengio, Geoffrey E. Hinton | 2015 |
# | Feature Pyramid Networks for Object Detection | Tsung-Yi Lin, Piotr Dollár, Ross B. Girshick, Kaiming He, Bharath Hariharan, Serge J. Belongie | 2016 |
# | Identity Mappings in Deep Residual Networks | Kaiming He, X. Zhang, Shaoqing Ren, Jian Sun | 2016 |
# | How transferable are features in deep neural networks? | J. Yosinski, J. Clune, Yoshua Bengio, Hod Lipson | 2014 |
# | Squeeze-and-Excitation Networks | Jie Hu, Li Shen, Samuel Albanie, Gang Sun, E. Wu | 2017 |
# | EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks | Mingxing Tan, Quoc V. Le | 2019 |
# | Deep Networks with Stochastic Depth | Gao Huang, Yu Sun, Zhuang Liu, Daniel Sedra, Kilian Q. Weinberger | 2016 |
# | Grad-CAM: Visual Explanations from Deep Networks via Gradient-Based Localization | Ramprasaath R. Selvaraju, Abhishek Das, Ramakrishna Vedantam, Michael Cogswell, Devi Parikh, Dhruv Batra | 2016 |
# | Focal Loss for Dense Object Detection | Tsung-Yi Lin, Priya Goyal, Ross B. Girshick, Kaiming He, Piotr Dollár | 2017 |
# | FractalNet: Ultra-Deep Neural Networks without Residuals | Gustav Larsson, M. Maire, Gregory Shakhnarovich | 2016 |
# | Residual Networks of Residual Networks: Multilevel Residual Networks | Ke Zhang, Miao Sun, T. Han, Xingfang Yuan, Liru Guo, Tao Liu | 2016 |
# | R-FCN: Object Detection via Region-based Fully Convolutional Networks | Jifeng Dai, Yi Li, Kaiming He, Jian Sun | 2016 |
# | The PASCAL Visual Object Classes (VOC) Challenge | — | — |
# | Long Short-Term Memory | Sepp Hochreiter, J. Schmidhuber | 1997 |
# | Untangling Local and Global Deformations in Deep Convolutional Networks for Image Classification and Sliding Window Detection | G. Papandreou, Iasonas Kokkinos, Pierre-André Savalle | 2014 |
# | OverFeat: Integrated Recognition, Localization and Detection using Convolutional Networks | P. Sermanet, D. Eigen, Xiang Zhang, Michaël Mathieu, R. Fergus, Yann LeCun | 2013 |
# | SORT: Second-Order Response Transform for Visual Recognition | Yan Wang, Lingxi Xie, Chenxi Liu, Ya Zhang, Wenjun Zhang, A. Yuille | 2017 |
# | Multiscale Multipath Ensemble Convolutional Neural Network | Xuesong Wang, Achun Bao, Enhui Lv, Yuhu Cheng | 2021 |
# | The Pascal Visual Object Classes Challenge: A Retrospective | M. Everingham, S. Eslami, L. Gool, Christopher K. I. Williams, J. Winn, Andrew Zisserman | 2014 |
# | Learning and Transferring Mid-level Image Representations Using Convolutional Neural Networks | M. Oquab, L. Bottou, I. Laptev, Josef Sivic | 2014 |
# | ADNet: Adaptively Dense Convolutional Neural Networks | Mingjie Wang, Hao Cai, Xin Huang, Minglun Gong | 2020 |
# | Rectified Linear Units Improve Restricted Boltzmann Machines | Vinod Nair, Geoffrey E. Hinton | 2010 |
# | Sparsely Aggregated Convolutional Networks | Ligeng Zhu, Ruizhi Deng, M. Maire, Zhiwei Deng, Greg Mori, P. Tan | 2018 |
# | Fisher vectors meet Neural Networks: A hybrid classification architecture | Florent Perronnin, Diane Larlus | 2015 |
# | DSSD: Deconvolutional Single Shot Detector | Cheng-Yang Fu, W. Liu, A. Ranga, A. Tyagi, A. Berg | 2017 |
